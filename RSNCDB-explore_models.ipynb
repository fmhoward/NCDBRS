# %% [markdown]
# # Imports
#
# First we have to import some packages to use down the line

# %%
import sys
import xgboost as xgb
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from lifelines import KaplanMeierFitter
from lifelines import CoxPHFitter
from lifelines.plotting import add_at_risk_counts
import sys
from tableone import TableOne
import sklearn
import math
import statsmodels.api as sm
import warnings
from sklearn.linear_model import LogisticRegression, LinearRegression, Lasso, LassoLarsIC, LassoCV, LassoLarsCV
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsRegressor
from sklearn.calibration import calibration_curve
import statsmodels.api as sm
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import log_loss
from sklearn.utils._testing import ignore_warnings
from sklearn.exceptions import ConvergenceWarning
import imblearn
import scipy
from imblearn.over_sampling import SMOTE
import time
import datetime
import openpyxl
import numpy.random as rng
import seaborn as sns
from scipy import stats
import pickle

from ncdb_tools import *
# Out:
# /home/asim/.conda/envs/ncdb/lib/python3.10/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
def warn(*args, **kwargs):
    pass

warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.simplefilter("ignore", category=ConvergenceWarning)
warnings.warn = warn

# %%
output_dir = "/home/asim/NCDB_Projects/test/gridsearch/"

# %% [markdown]
# # Loading the NCDB File
#
# First step is to properly load the NCDB file.
#
# Since loading the full NCDB csv takes quite some time, you can utilize the savefile and loadfile specifications to save a subset of the database once you've narrowed down to the patients / variables you are interested in.
#
# This next cell defines a 'function', we can then call the function later on in this notebook to get the actual results, running the code below just defines (as per def) the function. The function's name is load_data_her2. After the function, we specify parameters (filename, savefile, loadfile, and lower). You can provide default values for these parameters if you want using the equals sign - this means that the user doesn't need to provide these parameters every time the function is called.
#
# Detailed descriptions of all NCDB elements are found here:
# <a href="https://www.facs.org/-/media/files/quality-programs/cancer/ncdb/puf_data_dictionary_2017.ashx">https://www.facs.org/-/media/files/quality-programs/cancer/ncdb/puf_data_dictionary_2017.ashx</a>
#
# 'Site Specific Factors' are found here:
# <a href="https://web2.facs.org/cstage0205/breast/Breastschema.html">https://web2.facs.org/cstage0205/breast/Breastschema.html</a>

# %% [markdown]
# Let's demonstrate the use of our above NCDB accessing function. Replace the filename with your copy of NCDB.
#
# This code will take some time to execute! Try not to rerun it

# %%
df = load_data_her2(
    filename = r"/mnt/data/NCDB/NCDBPUF_Breast.0.2020.csv",
    lower = True
)
# Out:
# Total Patients in NCDB: 3690015
# Excluding diagnoses before 2010: 2594500
# Excluding non-invasive cases: 2100249
# Excluding cases where HER2+ or triple negative: 1583059
# Excluding cases where HER2 IHC isn't 0-2: 1583059
# Excluding Stage 0 cases: 1461118

# %%
#Adds the relevant important columns to the dataframe
df_new = getNCDBClassifications(df, use_imputation = False)
df_new = addTennNomogram(df_new)

# %%
#Minimal Feature Set:
mfs = ['age','sex', 'grade_med', 'grade_high', 'tumor_size', 'er', 'pr', 'regional_nodes_positive', 'skin_changes', 'lvi', 'chest_wall',
                     'ductal', 'lobular', 'ductlob', 'mucinous', 'tubular', 'medullary', 'metaplastic', 'paget', 'sarcoma', 'papillary', 'inflammatory',
                     'hispanic', 'native', 'asian', 'black', 'her2', 'er_num', 'pr_num', 'ki67_num']

# %%
print("Excluding stage 0: " + str(len(df_new.index)))

df_train = df_new[(df_new.regional_nodes_positive < 4)]
print("Excluding 4 or more nodes positive: " + str(len(df_train.index)))

df_train = df_train.dropna(subset = ['odx', 'high_odx'])
print("Excluding patients missing ODX: " + str(len(df_train.index)))

df_train = df_train.dropna(subset = mfs)
print("Excluding patients missing minimal feature set: " + str(len(df_train.index)))

# # use a smaller sample to speed up code initially
# frac = 0.1
# df_train = df_train.sample(frac = frac)
# print("Using %.1f%% of the data for initial code testing: %d" % (frac*100, df_train.shape[0]))
# Out:
# Excluding stage 0: 1461118
# Excluding 4 or more nodes positive: 1212847
# Excluding patients missing ODX: 399284
# Excluding patients missing minimal feature set: 53346

# %% [markdown]
# # Explore Models

# %%
# could check to optimize hyperparameters for logistic, but maybe not necessary
# penalty: {‘l1’, ‘l2’, ‘elasticnet’, None}
# C: [0.01, 0.1, 1, 10]
# fit_intercept: False, True
# solver: 'saga'

# %%
# %run ncdb_tools.py

# %%
model = LogisticRegression(max_iter = 1000, solver ='saga', n_jobs = -1)

params = {
    'model__penalty': {'l1', 'l2', None},
    'model__C': [0.01, 0.1, 1, 10],
    'model__fit_intercept': [False, True]
}

logistic_features = compareClassifiersNCDB(
    df_train[mfs + ['odx', 'high_odx']],
    model = model,
    params = params,
    maximizeAIC = True,
    her2_fish = False,
    ki67 = True,
    numerical = True,
    file_name = output_dir + "logistic_regression.txt"
)
# Out:
# Version Feature
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [86], in <cell line: 9>()
#       1 model = LogisticRegression(max_iter = 1000, solver ='saga', n_jobs = -1)
#       3 params = {
#       4     'model__penalty': {'elasticnet'},
#       5     'model__C': [0.01, 0.1, 1, 10],
#       6     'model__fit_intercept': [False, True]
#       7 }
# ----> 9 logistic_features = compareClassifiersNCDB(
#      10     df_train[mfs + ['odx', 'high_odx']],
#      11     model = model,
#      12     params = params,
#      13     maximizeAIC = True,
#      14     her2_fish = False,
#      15     ki67 = True,
#      16     numerical = True,
#      17     file_name = output_dir + "logistic_regression.txt"
#      18 )
#
# File ~/.conda/envs/ncdb/lib/python3.10/site-packages/sklearn/utils/_testing.py:188, in _IgnoreWarnings.__call__.<locals>.wrapper(*args, **kwargs)
#     186 with warnings.catch_warnings():
#     187     warnings.simplefilter("ignore", self.category)
# --> 188     return fn(*args, **kwargs)
#
# File ~/NCDB_Projects/test/ncdb_tools.py:2189, in compareClassifiersNCDB(df, model, params, her2_fish, ki67, numerical, maximizeAIC, includeTransforms, doWarmStart, file_name)
#    2186     f.write(" WITH QUANTITATIVE ER/PR AND HER2 FISH\n")
#    2187 f.close()
# -> 2189 return gridSearch(model, params, df, variable_list, weighted = False, warmStart = warmStart, maximizeAIC = maximizeAIC, file_name = file_name)
#
# File ~/.conda/envs/ncdb/lib/python3.10/site-packages/sklearn/utils/_testing.py:188, in _IgnoreWarnings.__call__.<locals>.wrapper(*args, **kwargs)
#     186 with warnings.catch_warnings():
#     187     warnings.simplefilter("ignore", self.category)
# --> 188     return fn(*args, **kwargs)
#
# File ~/NCDB_Projects/test/ncdb_tools.py:2266, in gridSearch(model, params, df, variable_list, weighted, warmStart, maximizeAIC, file_name)
#    2262 full_model = Pipeline([('poly', PolynomialFeatures(degree=1)),
#    2263                           ('model', model)])
#    2265 full_model.set_params(**p)
# -> 2266 _, _, _, results = feature_selection(
#    2267     df,
#    2268     variable_list,
#    2269     full_model,
#    2270     weighted,
#    2271     warmStart,
#    2272     maximizeAIC = maximizeAIC
#    2273 )
#    2275 ts = time.time()
#    2276 sttime = datetime.datetime.fromtimestamp(ts).strftime('%Y%m%d_%H:%M:%S - ')
#
# File ~/.conda/envs/ncdb/lib/python3.10/site-packages/sklearn/utils/_testing.py:188, in _IgnoreWarnings.__call__.<locals>.wrapper(*args, **kwargs)
#     186 with warnings.catch_warnings():
#     187     warnings.simplefilter("ignore", self.category)
# --> 188     return fn(*args, **kwargs)
#
# File ~/NCDB_Projects/test/ncdb_tools.py:1123, in feature_selection(df_new, variable_list, model, weighted, warmStart, maximizeAIC)
#    1121         scores += [100000000 - aic]
#    1122 else:
# -> 1123     model = model.fit(X, Y)
#    1124     probs = model.predict_proba(X)[:, 1]
#    1126     log_likelihood = -log_loss(Y, probs)
#
# File ~/.conda/envs/ncdb/lib/python3.10/site-packages/sklearn/pipeline.py:405, in Pipeline.fit(self, X, y, **fit_params)
#     403     if self._final_estimator != "passthrough":
#     404         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 405         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     407 return self
#
# File ~/.conda/envs/ncdb/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1291, in LogisticRegression.fit(self, X, y, sample_weight)
#    1288 else:
#    1289     n_threads = 1
# -> 1291 fold_coefs_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose, prefer=prefer)(
#    1292     path_func(
#    1293         X,
#    1294         y,
#    1295         pos_class=class_,
#    1296         Cs=[C_],
#    1297         l1_ratio=self.l1_ratio,
#    1298         fit_intercept=self.fit_intercept,
#    1299         tol=self.tol,
#    1300         verbose=self.verbose,
#    1301         solver=solver,
#    1302         multi_class=multi_class,
#    1303         max_iter=self.max_iter,
#    1304         class_weight=self.class_weight,
#    1305         check_input=False,
#    1306         random_state=self.random_state,
#    1307         coef=warm_start_coef_,
#    1308         penalty=penalty,
#    1309         max_squared_sum=max_squared_sum,
#    1310         sample_weight=sample_weight,
#    1311         n_threads=n_threads,
#    1312     )
#    1313     for class_, warm_start_coef_ in zip(classes_, warm_start_coef)
#    1314 )
#    1316 fold_coefs_, _, n_iter_ = zip(*fold_coefs_)
#    1317 self.n_iter_ = np.asarray(n_iter_, dtype=np.int32)[:, 0]
#
# File ~/.conda/envs/ncdb/lib/python3.10/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~/.conda/envs/ncdb/lib/python3.10/site-packages/joblib/parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File ~/.conda/envs/ncdb/lib/python3.10/site-packages/joblib/parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File ~/.conda/envs/ncdb/lib/python3.10/multiprocessing/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# File ~/.conda/envs/ncdb/lib/python3.10/multiprocessing/pool.py:125, in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123 job, i, func, args, kwds = task
#     124 try:
# --> 125     result = (True, func(*args, **kwds))
#     126 except Exception as e:
#     127     if wrap_exception and func is not _helper_reraises_exception:
#
# File ~/.conda/envs/ncdb/lib/python3.10/site-packages/joblib/_parallel_backends.py:620, in SafeFunction.__call__(self, *args, **kwargs)
#     618 def __call__(self, *args, **kwargs):
#     619     try:
# --> 620         return self.func(*args, **kwargs)
#     621     except KeyboardInterrupt as e:
#     622         # We capture the KeyboardInterrupt and reraise it as
#     623         # something different, as multiprocessing does not
#     624         # interrupt processing for a KeyboardInterrupt
#     625         raise WorkerInterrupt() from e
#
# File ~/.conda/envs/ncdb/lib/python3.10/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/.conda/envs/ncdb/lib/python3.10/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/.conda/envs/ncdb/lib/python3.10/site-packages/sklearn/utils/parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File ~/.conda/envs/ncdb/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:521, in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio, n_threads)
#     519     beta = 0.0
#     520 else:  # Elastic-Net penalty
# --> 521     alpha = (1.0 / C) * (1 - l1_ratio)
#     522     beta = (1.0 / C) * l1_ratio
#     524 w0, n_iter_i, warm_start_sag = sag_solver(
#     525     X,
#     526     target,
#    (...)
#     538     is_saga=(solver == "saga"),
#     539 )
#
# TypeError: unsupported operand type(s) for -: 'int' and 'NoneType'

# %%
model = sklearn.ensemble.RandomForestClassifier(
    n_estimators = 1, 
    max_features = None,
    n_jobs = -1
)

params = {
    'model__n_estimators': [100],
    'model__criterion': ['gini', 'entropy'],
    'model__max_depth': [None, 10, 50],
    'model__max_features': ['sqrt', 'log2', None],
    'poly__degree': [1,2]
}

forest_features = compareClassifiersNCDB(
    df_train[mfs + ['odx', 'high_odx']],
    model = model,
    params = params,
    maximizeAIC = True,
    her2_fish = False,
    ki67 = True,
    numerical = True,
    file_name = output_dir + "random_forest.txt"
)
# Out:
# Version Feature
# ['pr_num', 'sarcoma'] auc: 99999999.24709502 n: 53346
# {'model__n_estimators': 100, 'model__criterion': 'gini', 'model__max_depth': None, 'model__max_features': 'sqrt', 'poly__degree': 1} AUC: 0.7210502638111956 AIC: 0.7529049813747406 Features: ['pr_num', 'sarcoma']
# Version Feature
# ['pr_num', 'sarcoma'] auc: 99999999.24679513 n: 53346
# {'model__n_estimators': 100, 'model__criterion': 'gini', 'model__max_depth': None, 'model__max_features': 'sqrt', 'poly__degree': 2} AUC: 0.7209744708291554 AIC: 0.7532048672437668 Features: ['pr_num', 'sarcoma']
# Version Feature
# ['pr_num', 'sarcoma'] auc: 99999999.24717 n: 53346
# {'model__n_estimators': 100, 'model__criterion': 'gini', 'model__max_depth': None, 'model__max_features': 'log2', 'poly__degree': 1} AUC: 0.720944304191509 AIC: 0.7528299987316132 Features: ['pr_num', 'sarcoma']
# Version Feature
# ['pr_num', 'sarcoma'] auc: 99999999.24687009 n: 53346
# {'model__n_estimators': 100, 'model__criterion': 'gini', 'model__max_depth': None, 'model__max_features': 'log2', 'poly__degree': 2} AUC: 0.7208950153408896 AIC: 0.7531299144029617 Features: ['pr_num', 'sarcoma']
# Version Feature
# ['pr_num', 'sarcoma'] auc: 99999999.24657016 n: 53346
# {'model__n_estimators': 100, 'model__criterion': 'gini', 'model__max_depth': None, 'model__max_features': None, 'poly__degree': 1} AUC: 0.7211396274906277 AIC: 0.7534298449754715 Features: ['pr_num', 'sarcoma']
# Version Feature
# ['pr_num', 'sarcoma'] auc: 99999999.24702005 n: 53346
# {'model__n_estimators': 100, 'model__criterion': 'gini', 'model__max_depth': None, 'model__max_features': None, 'poly__degree': 2} AUC: 0.7212930043111889 AIC: 0.7529799491167068 Features: ['pr_num', 'sarcoma']
# Version Feature
# ['pr_num', 'paget'] auc: 99999999.3562691 n: 53346
# ['pr_num', 'paget', 'chest_wall'] auc: 99999999.39398515 n: 53346
# ['pr_num', 'paget', 'chest_wall', 'er'] auc: 99999999.46146914 n: 53346
# ['pr_num', 'paget', 'chest_wall', 'er', 'tubular'] auc: 99999999.53510165 n: 53346
# ['pr_num', 'paget', 'chest_wall', 'er', 'tubular', 'metaplastic'] auc: 99999999.59568726 n: 53346
# ['pr_num', 'paget', 'chest_wall', 'er', 'tubular', 'metaplastic', 'papillary'] auc: 99999999.64869966 n: 53346
# {'model__n_estimators': 100, 'model__criterion': 'gini', 'model__max_depth': 10, 'model__max_features': 'sqrt', 'poly__degree': 1} AUC: 0.725936384465821 AIC: 0.35130034387111664 Features: ['pr_num', 'paget', 'chest_wall', 'er', 'tubular', 'metaplastic', 'papillary']
# Version Feature
# ['pr_num', 'chest_wall'] auc: 99999999.36069308 n: 53346
# ['pr_num', 'chest_wall', 'metaplastic'] auc: 99999999.40628222 n: 53346
# ['pr_num', 'chest_wall', 'metaplastic', 'paget'] auc: 99999999.49941014 n: 53346
# ['pr_num', 'chest_wall', 'metaplastic', 'paget', 'tubular'] auc: 99999999.55444705 n: 53346
# ['pr_num', 'chest_wall', 'metaplastic', 'paget', 'tubular', 'papillary'] auc: 99999999.60610977 n: 53346
# ['pr_num', 'chest_wall', 'metaplastic', 'paget', 'tubular', 'papillary', 'inflammatory'] auc: 99999999.62500528 n: 53346
# ['pr_num', 'chest_wall', 'metaplastic', 'paget', 'tubular', 'papillary', 'inflammatory', 'medullary'] auc: 99999999.68686558 n: 53346
# {'model__n_estimators': 100, 'model__criterion': 'gini', 'model__max_depth': 10, 'model__max_features': 'sqrt', 'poly__degree': 2} AUC: 0.7259154180203774 AIC: 0.31313441693782806 Features: ['pr_num', 'chest_wall', 'metaplastic', 'paget', 'tubular', 'papillary', 'inflammatory', 'medullary']
# Version Feature
# ['pr_num', 'chest_wall'] auc: 99999999.3529699 n: 53346
# ['pr_num', 'chest_wall', 'paget'] auc: 99999999.39143576 n: 53346
# ['pr_num', 'chest_wall', 'paget', 'metaplastic'] auc: 99999999.46311875 n: 53346
# ['pr_num', 'chest_wall', 'paget', 'metaplastic', 'tubular'] auc: 99999999.53457677 n: 53346
# ['pr_num', 'chest_wall', 'paget', 'metaplastic', 'tubular', 'er'] auc: 99999999.59313786 n: 53346
# {'model__n_estimators': 100, 'model__criterion': 'gini', 'model__max_depth':
n: 53346
# {'model__n_estimators': 100, 'model__criterion': 'entropy', 'model__max_depth': 10, 'model__max_features': 'sqrt', 'poly__degree': 1} AUC: 0.7258921068245651 AIC: 0.35564932227134705 Features: ['pr_num', 'chest_wall', 'paget', 'er', 'tubular', 'metaplastic', 'medullary']
# Version Feature
# ['pr_num', 'chest_wall'] auc: 99999999.3727652 n: 53346
# ['pr_num', 'chest_wall', 'paget'] auc: 99999999.40785685 n: 53346
# ['pr_num', 'chest_wall', 'paget', 'metaplastic'] auc: 99999999.50683334 n: 53346
# ['pr_num', 'chest_wall', 'paget', 'metaplastic', 'tubular'] auc: 99999999.5761169 n: 53346
# ['pr_num', 'chest_wall', 'paget', 'metaplastic', 'tubular', 'papillary'] auc: 99999999.59936139 n: 53346
# ['pr_num', 'chest_wall', 'paget', 'metaplastic', 'tubular', 'papillary', 'medullary'] auc: 99999999.62493029 n: 53346
# ['pr_num', 'chest_wall', 'paget', 'metaplastic', 'tubular', 'papillary', 'medullary', 'skin_changes'] auc: 99999999.65724765 n: 53346
# ['pr_num', 'chest_wall', 'paget', 'metaplastic', 'tubular', 'papillary', 'medullary', 'skin_changes', 'inflammatory'] auc: 99999999.68769039 n: 53346
# {'model__n_estimators': 100, 'model__criterion': 'entropy', 'model__max_depth': 10, 'model__max_features': 'sqrt', 'poly__degree': 2} AUC: 0.7264849459901852 AIC: 0.3123096078634262 Features: ['pr_num', 'chest_wall', 'paget', 'metaplastic', 'tubular', 'papillary', 'medullary', 'skin_changes', 'inflammatory']
# Version Feature
# ['pr_num', 'chest_wall'] auc: 99999999.37089063 n: 53346
# ['pr_num', 'chest_wall', 'paget'] auc: 99999999.4039578 n: 53346
# ['pr_num', 'chest_wall', 'paget', 'er'] auc: 99999999.46949221 n: 53346
# ['pr_num', 'chest_wall', 'paget', 'er', 'tubular'] auc: 99999999.52610376 n: 53346
# ['pr_num', 'chest_wall', 'paget', 'er', 'tubular', 'metaplastic'] auc: 99999999.59786175 n: 53346
# {'model__n_estimators': 100, 'model__criterion': 'entropy', 'model__max_depth': 10, 'model__max_features': 'log2', 'poly__degree': 1} AUC: 0.7258678571508768 AIC: 0.40213824808597565 Features: ['pr_num', 'chest_wall', 'paget', 'er', 'tubular', 'metaplastic']
# Version Feature
# ['pr_num', 'chest_wall'] auc: 99999999.37141551 n: 53346
# ['pr_num', 'chest_wall', 'paget'] auc: 99999999.42247841 n: 53346
# ['pr_num', 'chest_wall', 'paget', 'tubular'] auc: 99999999.52085504 n: 53346
# ['pr_num', 'chest_wall', 'paget', 'tubular', 'metaplastic'] auc: 99999999.55684648 n: 53346
# ['pr_num', 'chest_wall', 'paget', 'tubular', 'metaplastic', 'inflammatory'] auc: 99999999.62965418 n: 53346
# ['pr_num', 'chest_wall', 'paget', 'tubular', 'metaplastic', 'inflammatory', 'medullary'] auc: 99999999.65319858 n: 53346
# ['pr_num', 'chest_wall', 'paget', 'tubular', 'metaplastic', 'inflammatory', 'medullary', 'sarcoma'] auc: 99999999.70043735 n: 53346
# ['pr_num', 'chest_wall', 'paget', 'tubular', 'metaplastic', 'inflammatory', 'medullary', 'sarcoma', 'skin_changes'] auc: 99999999.71265946 n: 53346
# {'model__n_estimators': 100, 'model__criterion': 'entropy', 'model__max_depth': 10, 'model__max_features': 'log2', 'poly__degree': 2} AUC: 0.72631915603866 AIC: 0.28734053671360016 Features: ['pr_num', 'chest_wall', 'paget', 'tubular', 'metaplastic', 'inflammatory', 'medullary', 'sarcoma', 'skin_changes']
# Version Feature
# ['pr_num', 'sarcoma'] auc: 99999999.33040024 n: 53346
# {'model__n_estimators': 100, 'model__criterion': 'entropy', 'model__max_depth': 10, 'model__max_features': None, 'poly__degree': 1} AUC: 0.721474112160076 AIC: 0.6695997565984726 Features: ['pr_num', 'sarcoma']
# Version Feature
# ['pr_num', 'sarcoma'] auc: 99999999.3301753 n: 53346
# {'model__n_estimators': 100, 'model__criterion': 'entropy', 'model__max_depth': 10, 'model__max_features': None, 'poly__degree': 2} AUC: 0.7216308136469717 AIC: 0.6698247045278549 Features: ['pr_num', 'sarcoma']
# Version Feature
# ['pr_num', 'sarcoma'] auc: 99999999.24739495 n: 53346
# {'model__n_estimators': 100, 'model__criterion': 'entropy', 'model__max_depth': 50, 'model__max_features': 'sqrt', 'poly__degree': 1} AUC: 0.7210182279224379 AIC: 0.7526050508022308 Features: ['pr_num', 'sarcoma']
# Version Feature
# ['pr_num', 'sarcoma'] auc: 99999999.24724498 n: 53346
# {'model__n_estimators': 100, 'model__criterion': 'entropy', 'model__max_depth': 50, 'model__max_features': 'sqrt', 'poly__degree': 2} AUC: 0.7205166844175275 AIC: 0.7527550160884857 Features: ['pr_num', 'sarcoma']
# Version Feature
# ['pr_num', 'sarcoma'] auc: 99999999.24724498 n: 53346
# {'model__n_estimators': 100, 'model__criterion': 'entropy', 'model__max_depth': 50, 'model__max_features': 'log2', 'poly__degree': 1} AUC: 0.720864254469222 AIC: 0.7527550160884857 Features: ['pr_num', 'sarcoma']
# Version Feature
# ['pr_num', 'sarcoma'] auc: 99999999.24687009 n: 53346
# {'model__n_estimators': 100, 'model__criterion': 'entropy', 'model__max_depth': 50, 'model__max_features': 'log2', 'poly__degree': 2} AUC: 0.7207795770803451 AIC: 0.7531299144029617 Features: ['pr_num', 'sarcoma']
# Version Feature
# ['pr_num', 'sarcoma'] auc: 99999999.24717 n: 53346
# {'model__n_estimators': 100, 'model__criterion': 'entropy', 'model__max_depth': 50, 'model__max_features': None, 'poly__degree': 1} AUC: 0.7207249076291351 AIC: 0.7528299987316132 Features: ['pr_num', 'sarcoma']
# Version Feature
# ['pr_num', 'sarcoma'] auc: 99999999.24687009 n: 53346
# {'model__n_estimators': 100, 'model__criterion': 'entropy', 'model__max_depth': 50, 'model__max_features': None, 'poly__degree': 2} AUC: 0.720483955674093 AIC: 0.7531299144029617 Features: ['pr_num', 'sarcoma']
# Best Model Params
# None
# AUC
# 0

# %%
# model = sklearn.neighbors.KNeighborsClassifier(
#     n_neighbors = 1, 
#     weights = 'uniform',
#     n_jobs = -1
# )

# params = {
#     'model__n_neighbors': [1, 5, 10, 25, 50, 100],
#     'model__weights': ['uniform', 'distance'],
#     'poly__degree': [1,2]
# }

# kneighbors_features1 = compareClassifiersNCDB(
#     df_train,
#     model = model,
#     params = params,
#     her2_fish = False,
#     ki67 = True,
#     numerical = True,
#     file_name = output_dir + "kneighbors1.txt"
# )

# %%
# model = sklearn.neighbors.KNeighborsClassifier(
#     n_neighbors = 1, 
#     weights = 'uniform',
#     n_jobs = -1
# )

# params = {
#     'model__n_neighbors': [100, 250, 500, 750, 1000],
#     'model__weights': ['uniform', 'distance'],
#     'poly__degree': [1,2]
# }

# kneighbors_features2 = compareClassifiersNCDB(
#     df_train,
#     model = model,
#     params = params,
#     her2_fish = False,
#     ki67 = True,
#     numerical = True,
#     file_name = output_dir + "kneighbors2.txt"
# )

# %%
model = sklearn.ensemble.AdaBoostClassifier(
    n_estimators = 1
)

params = {
    'model__n_estimators': [1, 5, 10, 50, 100, 500, 1000],
#     'model__loss': ['linear', 'square', 'exponential'],
    'poly__degree': [1,2]
}

adaboost_features = compareClassifiersNCDB(
    df_train[mfs + ['odx', 'high_odx']],
    model = model,
    params = params,
    maximizeAIC = True,
    her2_fish = False,
    ki67 = True,
    numerical = True,
    file_name = output_dir + "adaboost.txt"
)
# Out:
# Version Feature
# ['pr_num', 'age'] auc: 99999999.99987854 n: 53346
# {'model__n_estimators': 1, 'poly__degree': 1} AUC: 0.6698392332619183 AIC: 0.00012145936489105225 Features: ['pr_num', 'age']
# Version Feature
# ['pr_num', 'age'] auc: 99999999.99987856 n: 53346
# {'model__n_estimators': 1, 'poly__degree': 2} AUC: 0.6711466068522338 AIC: 0.0001214444637298584 Features: ['pr_num', 'age']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99942027 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99942052 n: 53346
# {'model__n_estimators': 5, 'poly__degree': 1} AUC: 0.7954599739115024 AIC: 0.0005794763565063477 Features: ['pr_num', 'ki67_num', 'grade_high']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99942027 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99942039 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'age'] auc: 99999999.99942051 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'age', 'ductal'] auc: 99999999.99942054 n: 53346
# {'model__n_estimators': 5, 'poly__degree': 2} AUC: 0.7942038100969552 AIC: 0.0005794614553451538 Features: ['pr_num', 'ki67_num', 'grade_high', 'age', 'ductal']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99885412 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99885425 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'grade_med'] auc: 99999999.9988543 n: 53346
# {'model__n_estimators': 10, 'poly__degree': 1} AUC: 0.8084681136312202 AIC: 0.0011457055807113647 Features: ['pr_num', 'ki67_num', 'grade_high', 'grade_med']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99885412 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99885419 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'age'] auc: 99999999.99885426 n: 53346
# {'model__n_estimators': 10, 'poly__degree': 2} AUC: 0.8014859544049553 AIC: 0.0011457353830337524 Features: ['pr_num', 'ki67_num', 'grade_high', 'age']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.9943514 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99435142 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'grade_med'] auc: 99999999.99435143 n: 53346
# {'model__n_estimators': 50, 'poly__degree': 1} AUC: 0.8150319893156073 AIC: 0.005648568272590637 Features: ['pr_num', 'ki67_num', 'grade_high', 'grade_med']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.9943514 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99435142 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'age'] auc: 99999999.99435143 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'age', 'grade_med'] auc: 99999999.99435148 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'age', 'grade_med', 'mucinous'] auc: 99999999.99435149 n: 53346
# {'model__n_estimators': 50, 'poly__degree': 2} AUC: 0.8127347490433985 AIC: 0.005648508667945862 Features: ['pr_num', 'ki67_num', 'grade_high', 'age', 'grade_med', 'mucinous']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.98872721 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.98872723 n: 53346
# {'model__n_estimators': 100, 'poly__degree': 1} AUC: 0.8120933145822692 AIC: 0.011272773146629333 Features: ['pr_num', 'ki67_num', 'grade_high']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.98872721 n: 53346
# ['pr_num', 'ki67_num', 'age'] auc: 99999999.98872723 n: 53346
# {'model__n_estimators': 100, 'poly__degree': 2} AUC: 0.7959920005777714 AIC: 0.011272773146629333 Features: ['pr_num', 'ki67_num', 'age']
# Version Feature
# ['pr_num', 'grade_high'] auc: 99999999.94373749 n: 53346
# {'model__n_estimators': 500, 'poly__degree': 1} AUC: 0.7854220838042133 AIC: 0.056262508034706116 Features: ['pr_num', 'grade_high']
# Version Feature
# ['pr_num', 'grade_high'] auc: 99999999.94373749 n: 53346
# {'model__n_estimators': 500, 'poly__degree': 2} AUC: 0.7860967198050763 AIC: 0.056262508034706116 Features: ['pr_num', 'grade_high']
# Version Feature
# ['pr_num', 'age'] auc: 99999999.88750078 n: 53346
# {'model__n_estimators': 1000, 'poly__degree': 1} AUC: 0.7270622055128341 AIC: 0.11249922215938568 Features: ['pr_num', 'age']
# Version Feature
# ['pr_num', 'age'] auc: 99999999.88750078 n: 53346
# {'model__n_estimators': 1000, 'poly__degree': 2} AUC: 0.7250923781906496 AIC: 0.11249922215938568 Features: ['pr_num', 'age']
# Best Model Params
# None
# AUC
# 0

# %%
model = sklearn.neural_network.MLPClassifier(
    hidden_layer_sizes = (10, 50, 100),
    activation = 'logistic',
    learning_rate_init = 0.01,
    alpha = 0.0001
)

params = {
    'model__hidden_layer_sizes': [(10,), (50,), (100,)],
    'model__activation': ['logistic', 'tanh', 'relu'],
    'model__learning_rate_init': [0.01, 0.001, 0.0001],
    'model__alpha': [0.0001, 0.00001],
    'poly__degree': [1,2]
}

nn_features1 = compareClassifiersNCDB(
    df_train[mfs + ['odx', 'high_odx']],
    model = model,
    params = params,
    maximizeAIC = True,
    her2_fish = False,
    ki67 = True,
    numerical = True,
    file_name = output_dir + "neuralnetwork1.txt"
)
# Out:
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99924202 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99924226 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'pr'] auc: 99999999.99924228 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'pr', 'sex'] auc: 99999999.99924229 n: 53346
# {'model__hidden_layer_sizes': (10,), 'model__activation': 'logistic', 'model__learning_rate_init': 0.01, 'model__alpha': 0.0001, 'poly__degree': 1} AUC: 0.8094877076417358 AIC: 0.0007577091455459595 Features: ['pr_num', 'ki67_num', 'grade_high', 'pr', 'sex']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99924126 n: 53346
# ['pr_num', 'ki67_num', 'tubular'] auc: 99999999.99924183 n: 53346
# {'model__hidden_layer_sizes': (10,), 'model__activation': 'logistic', 'model__learning_rate_init': 0.01, 'model__alpha': 0.0001, 'poly__degree': 2} AUC: 0.7079017970468113 AIC: 0.0007581710815429688 Features: ['pr_num', 'ki67_num', 'tubular']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99924204 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99924226 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'grade_med'] auc: 99999999.99924229 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'grade_med', 'ductal'] auc: 99999999.9992423 n: 53346
# {'model__hidden_layer_sizes': (10,), 'model__activation': 'logistic', 'model__learning_rate_init': 0.01, 'model__alpha': 1e-05, 'poly__degree': 1} AUC: 0.8142064986231345 AIC: 0.0007576942443847656 Features: ['pr_num', 'ki67_num', 'grade_high', 'grade_med', 'ductal']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999
num']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99249363 n: 53346
# ['pr_num', 'ki67_num', 'grade_med'] auc: 99999999.99249372 n: 53346
# ['pr_num', 'ki67_num', 'grade_med', 'grade_high'] auc: 99999999.99249391 n: 53346
# ['pr_num', 'ki67_num', 'grade_med', 'grade_high', 'lvi'] auc: 99999999.99249396 n: 53346
# ['pr_num', 'ki67_num', 'grade_med', 'grade_high', 'lvi', 'her2'] auc: 99999999.99249397 n: 53346
# {'model__hidden_layer_sizes': (100,), 'model__activation': 'relu', 'model__learning_rate_init': 0.001, 'model__alpha': 1e-05, 'poly__degree': 1} AUC: 0.8135009941299085 AIC: 0.007506027817726135 Features: ['pr_num', 'ki67_num', 'grade_med', 'grade_high', 'lvi', 'her2']
# Version Feature
# ['pr_num', 'metaplastic'] auc: 99999999.99249078 n: 53346
# {'model__hidden_layer_sizes': (100,), 'model__activation': 'relu', 'model__learning_rate_init': 0.001, 'model__alpha': 1e-05, 'poly__degree': 2} AUC: 0.692450315403045 AIC: 0.007509216666221619 Features: ['pr_num', 'metaplastic']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99249364 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99249385 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'er_num'] auc: 99999999.99249391 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'er_num', 'lobular'] auc: 99999999.99249397 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'er_num', 'lobular', 'grade_med'] auc: 99999999.99249399 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'er_num', 'lobular', 'grade_med', 'age'] auc: 99999999.992494 n: 53346
# {'model__hidden_layer_sizes': (100,), 'model__activation': 'relu', 'model__learning_rate_init': 0.0001, 'model__alpha': 0.0001, 'poly__degree': 1} AUC: 0.8191226842963741 AIC: 0.0075059980154037476 Features: ['pr_num', 'ki67_num', 'grade_high', 'er_num', 'lobular', 'grade_med', 'age']
# Version Feature
# ['pr_num', 'grade_high'] auc: 99999999.99249351 n: 53346
# ['pr_num', 'grade_high', 'grade_med'] auc: 99999999.99249353 n: 53346
# ['pr_num', 'grade_high', 'grade_med', 'lvi'] auc: 99999999.99249361 n: 53346
# ['pr_num', 'grade_high', 'grade_med', 'lvi', 'er'] auc: 99999999.99249364 n: 53346
# {'model__hidden_layer_sizes': (100,), 'model__activation': 'relu', 'model__learning_rate_init': 0.0001, 'model__alpha': 0.0001, 'poly__degree': 2} AUC: 0.7392746254029319 AIC: 0.0075063556432724 Features: ['pr_num', 'grade_high', 'grade_med', 'lvi', 'er']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99249364 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99249382 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'ductal'] auc: 99999999.9924939 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'ductal', 'er_num'] auc: 99999999.99249396 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'ductal', 'er_num', 'grade_med'] auc: 99999999.99249397 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'ductal', 'er_num', 'grade_med', 'tumor_size'] auc: 99999999.992494 n: 53346
# {'model__hidden_layer_sizes': (100,), 'model__activation': 'relu', 'model__learning_rate_init': 0.0001, 'model__alpha': 1e-05, 'poly__degree': 1} AUC: 0.8170395625717364 AIC: 0.0075059980154037476 Features: ['pr_num', 'ki67_num', 'grade_high', 'ductal', 'er_num', 'grade_med', 'tumor_size']
# Version Feature
# ['pr_num', 'grade_high'] auc: 99999999.99249335 n: 53346
# ['pr_num', 'grade_high', 'grade_med'] auc: 99999999.99249361 n: 53346
# {'model__hidden_layer_sizes': (100,), 'model__activation': 'relu', 'model__learning_rate_init': 0.0001, 'model__alpha': 1e-05, 'poly__degree': 2} AUC: 0.7635233582001282 AIC: 0.007506385445594788 Features: ['pr_num', 'grade_high', 'grade_med']
# Best Model Params
# None
# AUC
# 0

# %%
model = sklearn.neural_network.MLPClassifier(
    hidden_layer_sizes = (10, 50, 100),
    activation = 'logistic',
    learning_rate_init = 0.01,
    alpha = 0.0001
)

params = {
    'model__hidden_layer_sizes': [(10,10), (50,50), (100,100)],
    'model__activation': ['logistic', 'tanh', 'relu'],
    'model__learning_rate_init': [0.01, 0.001, 0.0001],
    'model__alpha': [0.0001, 0.00001],
    'poly__degree': [1,2]
}

nn_features2 = compareClassifiersNCDB(
    df_train[mfs + ['odx', 'high_odx']],
    model = model,
    params = params,
    maximizeAIC = True,
    her2_fish = False,
    ki67 = True,
    numerical = True,
    file_name = output_dir + "neuralnetwork2.txt"
)
# Out:
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99924196 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99924222 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'tumor_size'] auc: 99999999.99924228 n: 53346
# {'model__hidden_layer_sizes': (10, 10), 'model__activation': 'logistic', 'model__learning_rate_init': 0.01, 'model__alpha': 0.0001, 'poly__degree': 1} AUC: 0.8086086654539677 AIC: 0.0007577240467071533 Features: ['pr_num', 'ki67_num', 'grade_high', 'tumor_size']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.9992417 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99924181 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'regional_nodes_positive'] auc: 99999999.99924184 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'regional_nodes_positive', 'lobular'] auc: 99999999.99924186 n: 53346
# {'model__hidden_layer_sizes': (10, 10), 'model__activation': 'logistic', 'model__learning_rate_init': 0.01, 'model__alpha': 0.0001, 'poly__degree': 2} AUC: 0.6978860622210575 AIC: 0.0007581412792205811 Features: ['pr_num', 'ki67_num', 'grade_high', 'regional_nodes_positive', 'lobular']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99924202 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99924228 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'grade_med'] auc: 99999999.9992423 n: 53346
# {'model__hidden_layer_sizes': (10, 10), 'model__activation': 'logistic', 'model__learning_rate_init': 0.01, 'model__alpha': 1e-05, 'poly__degree': 1} AUC: 0.8128481610459319 AIC: 0.0007576942443847656 Features: ['pr_num', 'ki67_num', 'grade_high', 'grade_med']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99924181 n: 53346
# {'model__hidden_layer_sizes': (10, 10), 'model__activation': 'logistic', 'model__learning_rate_init': 0.01, 'model__alpha': 1e-05, 'poly__degree': 2} AUC: 0.723057174108979 AIC: 0.0007581859827041626 Features: ['pr_num', 'ki67_num']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99924205 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99924228 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'er_num'] auc: 99999999.9992423 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'er_num', 'grade_
n: 53346
# {'model__hidden_layer_sizes': (10, 10), 'model__activation': 'relu', 'model__learning_rate_init': 0.001, 'model__alpha': 0.0001, 'poly__degree': 2} AUC: 0.772565960136638 AIC: 0.000757947564125061 Features: ['pr_num', 'er', 'ki67_num', 'regional_nodes_positive', 'ductlob']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99924205 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99924229 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'er_num'] auc: 99999999.99924232 n: 53346
# {'model__hidden_layer_sizes': (10, 10), 'model__activation': 'relu', 'model__learning_rate_init': 0.001, 'model__alpha': 1e-05, 'poly__degree': 1} AUC: 0.8127369488964595 AIC: 0.0007576793432235718 Features: ['pr_num', 'ki67_num', 'grade_high', 'er_num']
# Version Feature
# ['pr_num', 'lvi'] auc: 99999999.9992414 n: 53346
# ['pr_num', 'lvi', 'grade_high'] auc: 99999999.99924178 n: 53346
# ['pr_num', 'lvi', 'grade_high', 'lobular'] auc: 99999999.99924196 n: 53346
# {'model__hidden_layer_sizes': (10, 10), 'model__activation': 'relu', 'model__learning_rate_init': 0.001, 'model__alpha': 1e-05, 'poly__degree': 2} AUC: 0.7329230890964756 AIC: 0.0007580369710922241 Features: ['pr_num', 'lvi', 'grade_high', 'lobular']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99924205 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99924228 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'grade_med'] auc: 99999999.99924229 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'grade_med', 'hispanic'] auc: 99999999.9992423 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'grade_med', 'hispanic', 'lobular'] auc: 99999999.99924232 n: 53346
# {'model__hidden_layer_sizes': (10, 10), 'model__activation': 'relu', 'model__learning_rate_init': 0.0001, 'model__alpha': 0.0001, 'poly__degree': 1} AUC: 0.8119112625712871 AIC: 0.0007576793432235718 Features: ['pr_num', 'ki67_num', 'grade_high', 'grade_med', 'hispanic', 'lobular']
# Version Feature
# ['pr_num', 'grade_high'] auc: 99999999.99924178 n: 53346
# ['pr_num', 'grade_high', 'lobular'] auc: 99999999.99924193 n: 53346
# ['pr_num', 'grade_high', 'lobular', 'grade_med'] auc: 99999999.99924204 n: 53346
# ['pr_num', 'grade_high', 'lobular', 'grade_med', 'black'] auc: 99999999.99924205 n: 53346
# ['pr_num', 'grade_high', 'lobular', 'grade_med', 'black', 'ki67_num'] auc: 99999999.99924216 n: 53346
# ['pr_num', 'grade_high', 'lobular', 'grade_med', 'black', 'ki67_num', 'ductlob'] auc: 99999999.99924219 n: 53346
# /home/asim/.conda/envs/ncdb/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ['pr_num', 'grade_high', 'lobular', 'grade_med', 'black', 'ki67_num', 'ductlob', 'ductal'] auc: 99999999.99924226 n: 53346
# {'model__hidden_layer_sizes': (10, 10), 'model__activation': 'relu', 'model__learning_rate_init': 0.0001, 'model__alpha': 0.0001, 'poly__degree': 2} AUC: 0.7983018389336494 AIC: 0.0007577389478683472 Features: ['pr_num', 'grade_high', 'lobular', 'grade_med', 'black', 'ki67_num', 'ductlob', 'ductal']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99924205 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99924219 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'er_num'] auc: 99999999.99924229 n: 53346
# {'model__hidden_layer_sizes': (10, 10), 'model__activation': 'relu', 'model__learning_rate_init': 0.0001, 'model__alpha': 1e-05, 'poly__degree': 1} AUC: 0.8112004574596083 AIC: 0.0007577091455459595 Features: ['pr_num', 'ki67_num', 'grade_high', 'er_num']
# Version Feature
# ['pr_num', 'mucinous'] auc: 99999999.99924135 n: 53346
# ['pr_num', 'mucinous', 'grade_high'] auc: 99999999.99924192 n: 53346
# ['pr_num', 'mucinous', 'grade_high', 'ki67_num'] auc: 99999999.99924196 n: 53346
# /home/asim/.conda/envs/ncdb/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ['pr_num', 'mucinous', 'grade_high', 'ki67_num', 'lobular'] auc: 99999999.99924208 n: 53346
# ['pr_num', 'mucinous', 'grade_high', 'ki67_num', 'lobular', 'regional_nodes_positive'] auc: 99999999.9992422 n: 53346
# /home/asim/.conda/envs/ncdb/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ['pr_num', 'mucinous', 'grade_high', 'ki67_num', 'lobular', 'regional_nodes_positive', 'black'] auc: 99999999.99924222 n: 53346
# /home/asim/.conda/envs/ncdb/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# {'model__hidden_layer_sizes': (10, 10), 'model__activation': 'relu', 'model__learning_rate_init': 0.0001, 'model__alpha': 1e-05, 'poly__degree': 2} AUC: 0.7840750800281432 AIC: 0.0007577836513519287 Features: ['pr_num', 'mucinous', 'grade_high', 'ki67_num', 'lobular', 'regional_nodes_positive', 'black']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99624275 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99624296 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'grade_med'] auc: 99999999.996243 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'grade_med', 'tumor_size'] auc: 99999999.99624301 n: 53346
# {'model__hidden_layer_sizes': (50, 50), 'model__activation': 'logistic', 'model__learning_rate_init': 0.01, 'model__alpha': 0.0001, 'poly__degree': 1} AUC: 0.8118405071716304 AIC: 0.003756985068321228 Features: ['pr_num', 'ki67_num', 'grade_high', 'grade_med', 'tumor_size']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99624237 n: 53346
# ['pr_num', 'ki67_num', 'lobular'] auc: 99999999.99624254 n: 53346
# ['pr_num', 'ki67_num', 'lobular', 'pr'] auc: 99999999.99624255 n: 53346
# ['pr_num', 'ki67_num', 'lobular', 'pr', 'inflammatory'] auc: 99999999.99624257 n: 53346
# ['pr_num', 'ki67_num', 'lobular', 'pr', 'inflammatory', 'regional_nodes_positive'] auc: 99999999.99624263 n: 53346
# {'model__hidden_layer_sizes': (50, 50), 'model__activation': 'logistic', 'model__learning_rate_init': 0.01, 'model__alpha': 0.0001, 'poly__degree': 2} AUC: 0.73562001407652 AIC: 0.003757372498512268 Features: ['pr_num', 'ki67_num', 'lobular', 'pr', 'inflammatory', 'regional_nodes_positive']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99624275 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99624297 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'grade_med'] auc: 99999999.99624299 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'grade_med', 'tumor_size'] auc: 99999999.99624301 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'grade_med', 'tumor_size', 'lobular'] auc: 99999999.99624304 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'grade_med', 'tumor_size', 'lobular', 'mucinous'] auc: 99999999.99624309 n: 53346
# {'model__hidden_layer_sizes': (50, 50), 'model__activation': 'logistic', 'model__learning_rate_init': 0.01, 'model__alpha': 1e-05, 'poly__degree': 1} AUC: 0.8109860324795429 AIC: 0.003756910562515259 Features: ['pr_num', 'ki67_num', 'grade_high', 'grade_med', 'tumor_size', 'lobular', 'mucinous']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.9962424 n: 53346
# ['pr_num', 'ki67_num', 'tumor_size'] auc: 99999999.99624254 n: 53346
# ['pr_num', 'ki67_num', 'tumor_size', 'asian'] auc: 99999999.99624255 n: 53346
# {'model__hidden_layer_sizes': (50, 50), 'model__activation': 'logistic', 'model__learning_rate_init': 0.01, 'model__alpha': 1e-05, 'poly__degree': 2} AUC: 0.736477808181524 AIC: 0.0037574470043182373 Features: ['pr_num', 'ki67_num', 'tumor_size', 'asian']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99624275 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99624299 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'er_num'] auc: 99999999.99624303 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'er_num', 'pr'] auc: 99999999.99624304 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'er_num', 'pr', 'lobular'] auc: 99999999.99624309 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'er_num', 'pr', 'lobular', 'age'] auc: 99999999.9962431 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'er_num', 'pr', 'lobular', 'age', 'grade_med'] auc: 99999999.99624313 n: 53346
# {'model__hidden_layer_sizes': (50, 50), 'model__activation': 'logistic', 'model__learning_rate_init': 0.001, 'model__alpha': 0.0001, 'poly__degree': 1} AUC: 0.8189490985946881 AIC: 0.0037568658590316772 Features: ['pr_num', 'ki67_num', 'grade_high', 'er_num', 'pr', 'lobular', 'age', 'grade_med']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99624264 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99624278 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'metaplastic'] auc: 99999999.99624288 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'metaplastic', 'lobular'] auc: 99999999.99624296 n: 53346
# {'model__hidden_layer_sizes': (50, 50), 'model__activation': 'logistic', 'model__learning_rate_init': 0.001, 'model__alpha': 0.0001, 'poly__degree': 2} AUC: 0.792884786248562 AIC: 0.0037570446729660034 Features: ['pr_num', 'ki67_num', 'grade_high', 'metaplastic', 'lobular']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99624275 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99624297 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'age'] auc: 99999999.99624301 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'age', 'er_num'] auc: 99999999.99624309 n: 53346
# {'model__hidden_layer_sizes': (50, 50), 'model__activation': 'logistic', 'model__learning_rate_init': 0.001, 'model__alpha': 1e-05, 'poly__degree': 1} AUC: 0.8146610171503854 AIC: 0.003756910562515259 Features: ['pr_num', 'ki67_num', 'grade_high', 'age', 'er_num']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99624266 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99624276 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'ductlob'] auc: 99999999.99624296 n: 53346
# {'model__hidden_layer_sizes': (50, 50), 'model__activation': 'logistic', 'model__learning_rate_init': 0.001, 'model__alpha': 1e-05, 'poly__degree': 2} AUC: 0.7882882348958297 AIC: 0.0037570446729660034 Features: ['pr_num', 'ki67_num', 'grade_high', 'ductlob']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99624275 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99624299 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'er_num'] auc: 99999999.996243 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'er_num', 'lobular'] auc: 99999999.99624304 n: 53346
# {'model__hidden_layer_sizes': (50, 50), 'model__activation': 'logistic', 'model__learning_rate_init': 0.0001, 'model__alpha': 0.0001, 'poly__degree': 1} AUC: 0.8135771714155396 AIC: 0.0037569552659988403 Features: ['pr_num', 'ki67_num', 'grade_high', 'er_num', 'lobular']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99624275 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99624297 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'ductal'] auc: 99999999.99624301 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'ductal', 'grade_med'] auc: 99999999.99624303 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'ductal', 'grade_med', 'ductlob'] auc: 99999999.9962431 n: 53346
# {'model__hidden_layer_sizes': (50, 50), 'model__activation': 'logistic', 'model__learning_rate_init': 0.0001, 'model__alpha': 0.0001, 'poly__degree': 2} AUC: 0.8123131423217466 AIC: 0.003756895661354065 Features: ['pr_num', 'ki67_num', 'grade_high', 'ductal', 'grade_med', 'ductlob']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99624275 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99624299 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'er_num'] auc: 99999999.99624301 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'er_num', 'tumor_size'] auc: 99999999.99624303 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'er_num', 'tumor_size', 'age'] auc: 99999999.99624304 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'er_num', 'tumor_size', 'age', 'ductal'] auc: 99999999.99624309 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'er_num', 'tumor_size', 'age', 'ductal', 'grade_med'] auc: 99999999.9962431 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'er_num', 'tumor_size', 'age', 'ductal', 'grade_med', 'medullary'] auc: 99999999.99624313 n: 53346
# {'model__hidden_layer_sizes': (50, 50), 'model__activation': 'logistic', 'model__learning_rate_init': 0.0001, 'model__alpha': 1e-05, 'poly__degree': 1} AUC: 0.8140767981769017 AIC: 0.0037568658590316772 Features: ['pr_num', 'ki67_num', 'grade_high', 'er_num', 'tumor_size', 'age', 'ductal', 'grade_med', 'medullary']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99624275 n: 53346
# ['pr_num', 'ki67_num', 'grade_high'] auc: 99999999.99624299 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'ductal'] auc: 99999999.99624301 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'ductal', 'grade_med'] auc: 99999999.99624303 n: 53346
# ['pr_num', 'ki67_num', 'grade_high', 'ductal', 'grade_med', 'er'] auc: 99999999.99624309 n: 53346
# {'model__hidden_layer_sizes': (50, 50), 'model__activation': 'logistic', 'model__learning_rate_init': 0.0001, 'model__alpha': 1e-05, 'poly__degree': 2} AUC: 0.811315216570771 AIC: 0.003756910562515259 Features: ['pr_num', 'ki67_num', 'grade_high', 'ductal', 'grade_med', 'er']
# Version Feature
# ['pr_num', 'ki67_num'] auc: 99999999.99624266 n: 53346
# ['pr_num', 'ki67_num', 'lobular'] auc: 99999999.99624267 n: 53346
